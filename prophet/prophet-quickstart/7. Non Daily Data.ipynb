# %% [markdown]
# # 1. Package and Data Load

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
df = pd.read_csv('../prophet-quickstart/examples/example_yosemite_temps.csv')

# %% [markdown]
# # 2. Subdaily

# %%
m = Prophet(changepoint_prior_scale=0.01).fit(df)
future = m.make_future_dataframe(periods=300, freq='H')
fcst = m.predict(future)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /Users/sailyourlife/anaconda3/envs/nextopt/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m.plot(fcst)
m.plot_components(fcst)

# %% [markdown]
# # 3. Monthly Data

# %%
df = pd.read_csv('../prophet-quickstart/examples/example_retail_sales.csv')
m = Prophet().fit(df)
future = m.make_future_dataframe(periods=3652)
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /Users/sailyourlife/anaconda3/envs/nextopt/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
df.head()
# Out:
#            ds       y
# 0  1992-01-01  146376
# 1  1992-02-01  147079
# 2  1992-03-01  159336
# 3  1992-04-01  163669
# 4  1992-05-01  170068

# %%
future = m.make_future_dataframe(periods=120, freq='M')
future.head()
# Out:
#           ds
# 0 1992-01-01
# 1 1992-02-01
# 2 1992-03-01
# 3 1992-04-01
# 4 1992-05-01

# %%
future.tail()
# Out:
#             ds
# 408 2025-12-31
# 409 2026-01-31
# 410 2026-02-28
# 411 2026-03-31
# 412 2026-04-30

# %%
fcst = m.predict(future)
future = m.make_future_dataframe(periods=120, freq='M')
m.plot(fcst)
